# %% [markdown]
# # Aufgabe 34: Ballon Experiment
#
# ## Teilaufgabe a)
#
# Der Fluss der kosmischen Strahlung soll konstant im Messzeitraum sein.
# Die Zahl der gemessenen Protonen kann mit einer Poissonverteilung modelliert werden.
# Daher ergibt sich die Maximum-Likelihood-Funktion als:
#
# \begin{align*}
# L(\lambda) = \prod_{i} P(X = x_i)
# \end{align*}
#
# wobei wie oben beschrieben:
#
# \begin{align*}
# P(X) = \frac{\lambda^x}{x!}exp(-\lambda)
# \end{align*}
#
# Es ergibt sich
#
# \begin{align*}
# L(\lambda) &= \frac{\lambda^{4135}}{4135!}exp(-\lambda)\frac{\lambda^{4202}}{4202!}exp(-\lambda)\frac{\lambda^{4203}}{4203!}exp(-\lambda)\frac{\lambda^{4218}}{4218!}exp(-\lambda)\frac{\lambda^{4227}}{4227!}exp(-\lambda)
# \frac{\lambda^{4231}}{4231!}exp(-\lambda)\frac{\lambda^{4310}}{4310!}exp(-\lambda) \\ &= \frac{\lambda^{29526}}{4135!\cdot4202!\cdot4203!\cdot4218!\cdot4227!\cdot4231!\cdot4310!}exp(-7\lambda)
# \end{align*}
#
# Logarithmieren:
#
# \begin{align*}
# l(\lambda) &= ln(L(\lambda)) = 29526\cdot ln(\lambda) - 7\lambda - ln(4135!\cdot4202!\cdot4203!\cdot4218!\cdot4227!\cdot4231!\cdot4310!) \\
# &\approx 29526\cdot ln(\lambda) - 7\lambda - 216968,51
# \end{align*}
#
# Ableiten:
#
# \begin{align*}
# \frac{l(\lambda)}{d\lambda} = 29526\cdot \frac{1}{\lambda} - 7
# \end{align*}
#
# Die Ableitung hat eine Nullstelle bei
#
# \begin{align*}
# \lambda = 4218
# \end{align*}
#
# Die wahrscheinlichste Zählrate ist also $N = 4218$.
#
# Es ergibt sich ein log-Likelihood-Wert von
#
# \begin{align*}
# l(4218) = -37,55
# \end{align*}
#
# Und damit ein Likelihood-Wert von
#
# \begin{align*}
# L(4218) = e^{-37,55} = 4,92\cdot 10^{-17}
# \end{align*}

# %% [markdown]
# ## Teilaufgabe b)
# Der Fluss soll linear ansteigen. Also ändert sich der Mittelwert der Poissonverteilung jeweils linear während der 7 Tage.
# Die Maximum-Likelihood-Funktion lautet dann
#
# \begin{align*}
# L(\lambda) &= \frac{\lambda^{4135}}{4135!}exp(-\lambda)\frac{\left(2\lambda\right)^{4202}}{4202!}exp(-2\lambda)\frac{(3\lambda)^{4203}}{4203!}exp(-3\lambda)\frac{(4\lambda)^{4218}}{4218!}exp(-4\lambda)\frac{(5\lambda)^{4227}}{4227!}exp(-5\lambda)
# \frac{(6\lambda)^{4231}}{4231!}exp(-6\lambda)\frac{(7\lambda)^{4310}}{4310!}exp(-7\lambda)
# \end{align*}
#
# Logarithmieren:
#
# \begin{align*}
# l(\lambda) &= 29526\cdot ln(\lambda) - 28\lambda + 4202\cdot ln(2) + 4203\cdot ln(3) + 4218\cdot ln(4) + 4227\cdot ln(5) + 4231\cdot ln(6) + 4310\cdot ln(7) - ln(4135!\cdot4202!\cdot4203!\cdot4218!\cdot4227!\cdot4231!\cdot4310!) \\ &\approx 29526\cdot ln(\lambda) - 28\lambda - 180820,15
# \end{align*}
#
# Ableiten:
#
# \begin{align*}
# \frac{l(\lambda)}{d\lambda} = 29526\cdot \frac{1}{\lambda} - 28
# \end{align*}
#
# Die Nullstelle lautet hier entsprechend
#
# \begin{align*}
# \lambda = 1054.5
# \end{align*}
#
# Dieser Wert bezeichnet hier jedoch nicht den Mittelwert selbst, sondern den Flussparameter.
#
# Es ergibt sich ein log-Likelihood-Wert von
#
# \begin{align*}
# l(1054,5) = -4820,92
# \end{align*}
#
# Und damit ein Likelihood-Wert von
#
# \begin{align*}
# L(1054,5) = e^{-4820,92} = ...
# \end{align*}

# %% [markdown]
# ## Teilaufgabe c)
#
# ### Konstanter Fluss
#
# Es ergibt sich
#
# \begin{align*}
# L(\lambda) &= \frac{\lambda^{4135}}{4135!}exp(-\lambda)\frac{\lambda^{4202}}{4202!}exp(-\lambda)\frac{\lambda^{4203}}{4203!}exp(-\lambda)\frac{\lambda^{4218}}{4218!}exp(-\lambda)\frac{\lambda^{4227}}{4227!}exp(-\lambda)
# \frac{\lambda^{4231}}{4231!}exp(-\lambda)\frac{\lambda^{4310}}{4310!}exp(-\lambda)\frac{\lambda^{4402}}{4402!}exp(-\lambda) \\ &= \frac{\lambda^{33928}}{4135!\cdot4202!\cdot4203!\cdot4218!\cdot4227!\cdot4231!\cdot4310!\cdot4402!}exp(-8\lambda)
# \end{align*}
#
# Logarithmieren:
#
# \begin{align*}
# l(\lambda) &= ln(L(\lambda)) = 33928\cdot ln(\lambda) - 8\lambda - ln(4135!\cdot4202!\cdot4203!\cdot4218!\cdot4227!\cdot4231!\cdot4310!\cdot4402!) \\
# &\approx 33928\cdot ln(\lambda) - 8\lambda - 249503,59
# \end{align*}
#
# Ableiten:
#
# \begin{align*}
# \frac{l(\lambda)}{d\lambda} = 33928\cdot \frac{1}{\lambda} - 8
# \end{align*}
#
# Die Ableitung hat eine Nullstelle bei
#
# \begin{align*}
# \lambda = 4241
# \end{align*}
#
# Die wahrscheinlichste Zählrate ist also $N = 4241$.
#
# Es ergibt sich ein log-Likelihood-Wert von
#
# \begin{align*}
# l(4241) = -46,13
# \end{align*}
#
# Und damit ein Likelihood-Wert von
#
# \begin{align*}
# L(4241) = e^{-46.13} = 9,25\cdot 10^{-21}
# \end{align*}
#
# ### Linear ansteigender Fluss
#
# \begin{align*}
# L(\lambda) &= \frac{\lambda^{4135}}{4135!}exp(-\lambda)\frac{\left(2\lambda\right)^{4202}}{4202!}exp(-2\lambda)\frac{(3\lambda)^{4203}}{4203!}exp(-3\lambda)\frac{(4\lambda)^{4218}}{4218!}exp(-4\lambda)\frac{(5\lambda)^{4227}}{4227!}exp(-5\lambda)
# \frac{(6\lambda)^{4231}}{4231!}exp(-6\lambda)\frac{(7\lambda)^{4310}}{4310!}exp(-7\lambda)\frac{(14\lambda)^{4402}}{4402!}exp(-14\lambda)
# \end{align*}
#
# Logarithmieren:
#
# \begin{align*}
# l(\lambda) &= 33928\cdot ln(\lambda) - 42\lambda + 4202\cdot ln(2) + 4203\cdot ln(3) + 4218\cdot ln(4) + 4227\cdot ln(5) + 4231\cdot ln(6) + 4310\cdot ln(7) + 4402\cdot ln(14) - ln(4135!\cdot4202!\cdot4203!\cdot4218!\cdot4227!\cdot4231!\cdot4310!\cdot4402!) \\ &\approx 33928\cdot ln(\lambda) - 42\lambda - 201738,09
# \end{align*}
#
# Ableiten:
#
# \begin{align*}
# \frac{l(\lambda)}{d\lambda} = 33928\cdot \frac{1}{\lambda} - 42
# \end{align*}
#
# Die Nullstelle lautet hier entsprechend
#
# \begin{align*}
# \lambda = 807,81
# \end{align*}
#
# Dieser Wert bezeichnet hier jedoch nicht den Mittelwert selbst, sondern den Flussparameter.
#
# Es ergibt sich ein log-Likelihood-Wert von
#
# \begin{align*}
# l(807,81) = -8540.99
# \end{align*}
#
# Und damit ein Likelihood-Wert von
#
# \begin{align*}
# L(807,81) = e^{-8540.99} = ...
# \end{align*}
